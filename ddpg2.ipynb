# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
working_directory = '/content/drive/Shareddrives/Vinci_v2'
os.chdir(working_directory)

# %%
import utils
import train
import test
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Loaded all models from directory: /content/drive/Shareddrives/Vinci_v2/models/creator

# %%
history = train.train()
# Out:
# episode number: 1 | episodic reward = -0.7054409727454188 | number of strokes = 40
# <PIL.Image.Image image mode=L size=48x48 at 0x7F6F6DC6A590>
# episode number: 2 | episodic reward = -0.07828628689050675 | number of strokes = 40
# <PIL.Image.Image image mode=L size=48x48 at 0x7F6F6DC94E50>
# episode number: 3 | episodic reward = -0.47916563697159315 | number of strokes = 40
# <PIL.Image.Image image mode=L size=48x48 at 0x7F6F6DC07C10>
# episode number: 4 | episodic reward = -0.795463151559234 | number of strokes = 40
# <PIL.Image.Image image mode=L size=48x48 at 0x7F6F6DC07DD0>
# episode number: 5 | episodic reward = -0.5931884407997133 | number of strokes = 40
# <PIL.Image.Image image mode=L size=48x48 at 0x7F6F6DAEDBD0>
# episode number: 6 | episodic reward = -0.7882890540361408 | number of strokes = 40
# <PIL.Image.Image image mode=L size=48x48 at 0x7F6F6DC6A850>
# episode number: 7 | episodic reward = -0.3086395409703255 | number of strokes = 40
# ...

# %%
utils.plot_reward(history)
# Out:
# Plot saved to ./results/creator/final_reward.png

# %%
train.test()
test.get_ground_truth(True)
# Out:
# <PIL.Image.Image image mode=L size=48x48 at 0x7F6EE97D1B90>
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# <PIL.Image.Image image mode=L size=48x48 at 0x7F6EEAA0A5D0>
